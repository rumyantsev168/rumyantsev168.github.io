# %% [markdown]
# ## This is my first ever Jupyter Notebook!
#
# Let's see what I can do here...
#
# Oh look! It's _basic_ **MarkDown** formatting!
#
# ```python
# print("Fake Hello World")
# ```

# %%
print("Real Hello World!")  # I can write and run this code!
# Out:
# Real Hello World!

# %% [markdown]
# $$
# \text{This thing even has \LaTeX}
# \\[10px]
# \begin{cases}
#     x + y = 7 \newline
#     x^2 + y^2 = 25
# \end{cases}
# $$

# %% [markdown]
# <div style="text-align: center">
#     <p>This is awesome!<p>
#     <img src=https://rumyantsev168.github.io/static/cats.gif>
# </div>
